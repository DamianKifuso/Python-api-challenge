# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime  import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 599

# %%
# set units for search
units = "metric"

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 623

# %%
# set units for search
units = "metric"

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = city_url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"
# print (url)

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-" * 15)

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------
# Processing Record 1 of Set 1 | sitka
# Processing Record 2 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 3 of Set 1 | grytviken
# Processing Record 4 of Set 1 | isafjordur
# Processing Record 5 of Set 1 | san ignacio
# Processing Record 6 of Set 1 | avarua
# Processing Record 7 of Set 1 | la passe
# Processing Record 8 of Set 1 | jamaame
# Processing Record 9 of Set 1 | egilsstadir
# Processing Record 10 of Set 1 | kargasok
# Processing Record 11 of Set 1 | suva
# Processing Record 12 of Set 1 | olinda
# Processing Record 13 of Set 1 | port elizabeth
# Processing Record 14 of Set 1 | benguela
# Processing Record 15 of Set 1 | tiksi
# Processing Record 16 of Set 1 | qaqortoq
# Processing Record 17 of Set 1 | rongelap
# Processing Record 18 of Set 1 | waitangi
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | flying fish cove
# Processing Record 22 of Set 1 | iqaluit
# Processing Record 23 of Set 1 | udachny
# Processing Record 24 of Set 1 | amga
# Processing Record 25 of Set 1 | edinburgh of the seven seas
# Processing Record 26 of Set 1 | recani
# Processing Record 27 of Set 1 | mil'kovo
# Processing Record 28 of Set 1 | pingdingshan
# Processing Record 29 of Set 1 | mansa
# Processing Record 30 of Set 1 | jayapura
# Processing Record 31 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 32 of Set 1 | olonkinbyen
# Processing Record 33 of Set 1 | tura
# Processing Record 34 of Set 1 | sakchu-up
# Processing Record 35 of Set 1 | queenstown
# Processing Record 36 of Set 1 | taruma
# Processing Record 37 of Set 1 | kapit
# Processing Record 38 of Set 1 | port-aux-francais
# Processing Record 39 of Set 1 | turtas
# Processing Record 40 of Set 1 | hawaiian paradise park
# Processing Record 41 of Set 1 | howard springs
# Processing Record 42 of Set 1 | guiren
# Processing Record 43 of Set 1 | bairnsdale
# Processing Record 44 of Set 1 | uthal
# Processing Record 45 of Set 1 | iskateley
# Processing Record 46 of Set 1 | segezha
# Processing Record 47 of Set 1 | silsbee
# Processing Record 48 of Set 1 | kununurra
# Processing Record 49 of Set 1 | bovalino
# Processing Record 50 of Set 1 | adamstown
# Processing Record 0 of Set 2 | lingdong
# Processing Record 1 of Set 2 | kirakira
# Processing Record 2 of Set 2 | ilulissat
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | las rosas
# Processing Record 5 of Set 2 | pisco
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | codrington
# Processing Record 8 of Set 2 | coquimbo
# Processing Record 9 of Set 2 | quellon
# Processing Record 10 of Set 2 | alice springs
# Processing Record 11 of Set 2 | 'anat al qadimah
# Processing Record 12 of Set 2 | west island
# Processing Record 13 of Set 2 | blackmans bay
# Processing Record 14 of Set 2 | nemuro
# Processing Record 15 of Set 2 | rio grande
# Processing Record 16 of Set 2 | puerto baquerizo moreno
# Processing Record 17 of Set 2 | margaret river
# Processing Record 18 of Set 2 | puerto natales
# Processing Record 19 of Set 2 | devinuwara
# City not found. Skipping...
# Processing Record 20 of Set 2 | nigde
# Processing Record 21 of Set 2 | bay city
# Processing Record 22 of Set 2 | ishigaki
# Processing Record 23 of Set 2 | prince rupert
# Processing Record 24 of Set 2 | katabu
# Processing Record 25 of Set 2 | zheleznogorsk-ilimskiy
# Processing Record 26 of Set 2 | naryn
# Processing Record 27 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 28 of Set 2 | wailua homesteads
# Processing Record 29 of Set 2 | chonchi
# Processing Record 30 of Set 2 | santa ana
# Processing Record 31 of Set 2 | swakopmund
# Processing Record 32 of Set 2 | tsiombe
# Processing Record 33 of Set 2 | richards bay
# Processing Record 34 of Set 2 | ras gharib
# City not found. Skipping...
# Processing Record 35 of Set 2 | asha
# Processing Record 36 of Set 2 | bandarbeyla
# Processing Record 37 of Set 2 | vikhorevka
# Processing Record 38 of Set 2 | zaozersk
# Processing Record 39 of Set 2 | dunedin
# Processing Record 40 of Set 2 | toga village
# City not found. Skipping...
# Processing Record 41 of Set 2 | strathmore
# Processing Record 42 of Set 2 | sisimiut
# Processing Record 43 of Set 2 | kurchatov
# Processing Record 44 of Set 2 | zouerate
# Processing Record 45 of Set 2 | saint augustine beach
# Processing Record 46 of Set 2 | dudinka
# Processing Record 47 of Set 2 | hengyang
# Processing Record 48 of Set 2 | boundiali
# Processing Record 49 of Set 2 | lago da pedra
# Processing Record 0 of Set 3 | vallenar
# Processing Record 1 of Set 3 | eceabat
# Processing Record 2 of Set 3 | katsuura
# Processing Record 3 of Set 3 | hasaki
# Processing Record 4 of Set 3 | st. john's
# Processing Record 5 of Set 3 | constantia
# Processing Record 6 of Set 3 | bereeda
# Processing Record 7 of Set 3 | kenora
# Processing Record 8 of Set 3 | bethel
# Processing Record 9 of Set 3 | sweet home
# Processing Record 10 of Set 3 | happy valley-goose bay
# Processing Record 11 of Set 3 | remire-montjoly
# Processing Record 12 of Set 3 | anadyr
# Processing Record 13 of Set 3 | thompson
# Processing Record 14 of Set 3 | aasiaat
# Processing Record 15 of Set 3 | monkey bay
# Processing Record 16 of Set 3 | polyarnyy
# Processing Record 17 of Set 3 | vorgashor
# Processing Record 18 of Set 3 | ambon
# Processing Record 19 of Set 3 | tchintabaraden
# Processing Record 20 of Set 3 | kotlas
# Processing Record 21 of Set 3 | yellowknife
# Processing Record 22 of Set 3 | bangjun
# Processing Record 23 of Set 3 | badger
# Processing Record 24 of Set 3 | chandbali
# Processing Record 25 of Set 3 | howrah
# Processing Record 26 of Set 3 | susuman
# Processing Record 27 of Set 3 | champerico
# Processing Record 28 of Set 3 | huarmey
# Processing Record 29 of Set 3 | hadibu
# Processing Record 30 of Set 3 | alofi
# Processing Record 31 of Set 3 | pangoa
# Processing Record 32 of Set 3 | sur
# Processing Record 33 of Set 3 | tazovsky
# Processing Record 34 of Set 3 | natal
# Processing Record 35 of Set 3 | fuvahmulah
# City not found. Skipping...
# Processing Record 36 of Set 3 | hermanus
# Processing Record 37 of Set 3 | borskoye
# Processing Record 38 of Set 3 | tubarao
# Processing Record 39 of Set 3 | huilong
# Processing Record 40 of Set 3 | carnarvon
# Processing Record 41 of Set 3 | atafu village
# Processing Record 42 of Set 3 | mpulungu
# Processing Record 43 of Set 3 | bardai
# Processing Record 44 of Set 3 | beberibe
# Processing Record 45 of Set 3 | kone
# Processing Record 46 of Set 3 | lerwick
# Processing Record 47 of Set 3 | bilibino
# Processing Record 48 of Set 3 | nagqu
# Processing Record 49 of Set 3 | college
# Processing Record 0 of Set 4 | grand-lahou
# Processing Record 1 of Set 4 | karatuzskoye
# Processing Record 2 of Set 4 | papatowai
# Processing Record 3 of Set 4 | visby
# Processing Record 4 of Set 4 | hotan
# Processing Record 5 of Set 4 | nizhneudinsk
# Processing Record 6 of Set 4 | fale old settlement
# Processing Record 7 of Set 4 | yuzhno-kurilsk
# Processing Record 8 of Set 4 | tobi village
# City not found. Skipping...
# Processing Record 9 of Set 4 | pekanbaru
# Processing Record 10 of Set 4 | hithadhoo
# Processing Record 11 of Set 4 | lihue
# Processing Record 12 of Set 4 | klyuchi
# Processing Record 13 of Set 4 | holualoa
# Processing Record 14 of Set 4 | talnakh
# Processing Record 15 of Set 4 | solwezi
# Processing Record 16 of Set 4 | ariyalur
# Processing Record 17 of Set 4 | luderitz
# Processing Record 18 of Set 4 | hamilton
# Processing Record 19 of Set 4 | ayabaca
# Processing Record 20 of Set 4 | ribeira grande
# Processing Record 21 of Set 4 | quarteira
# Processing Record 22 of Set 4 | al kharijah
# Processing Record 23 of Set 4 | sao vicente
# Processing Record 24 of Set 4 | vilyuchinsk
# Processing Record 25 of Set 4 | khandyga
# Processing Record 26 of Set 4 | sretensk
# Processing Record 27 of Set 4 | dwarka
# Processing Record 28 of Set 4 | casper
# Processing Record 29 of Set 4 | stanley
# Processing Record 30 of Set 4 | maiurno
# Processing Record 31 of Set 4 | sinabang
# Processing Record 32 of Set 4 | tommot
# Processing Record 33 of Set 4 | broken hill
# Processing Record 34 of Set 4 | punta arenas
# Processing Record 35 of Set 4 | invercargill
# Processing Record 36 of Set 4 | novokayakent
# Processing Record 37 of Set 4 | kolo
# Processing Record 38 of Set 4 | hinton
# Processing Record 39 of Set 4 | port blair
# Processing Record 40 of Set 4 | minas de marcona
# Processing Record 41 of Set 4 | longyearbyen
# Processing Record 42 of Set 4 | xiamen
# Processing Record 43 of Set 4 | kodiak
# Processing Record 44 of Set 4 | whitehorse
# Processing Record 45 of Set 4 | inarajan village
# Processing Record 46 of Set 4 | samana
# Processing Record 47 of Set 4 | chibougamau
# Processing Record 48 of Set 4 | kirensk
# Processing Record 49 of Set 4 | puerto ayora
# Processing Record 0 of Set 5 | kavaratti
# Processing Record 1 of Set 5 | el bauga
# Processing Record 2 of Set 5 | bridgewater
# Processing Record 3 of Set 5 | puerto san carlos
# City not found. Skipping...
# Processing Record 4 of Set 5 | nabire
# Processing Record 5 of Set 5 | ascension
# Processing Record 6 of Set 5 | san ignacio de velasco
# Processing Record 7 of Set 5 | hovd
# Processing Record 8 of Set 5 | okhotsk
# Processing Record 9 of Set 5 | jean-rabel
# Processing Record 10 of Set 5 | kapa'a
# Processing Record 11 of Set 5 | ushuaia
# Processing Record 12 of Set 5 | ha'il
# Processing Record 13 of Set 5 | farmington
# Processing Record 14 of Set 5 | miquelon
# Processing Record 15 of Set 5 | bel ombre
# Processing Record 16 of Set 5 | kegums
# Processing Record 17 of Set 5 | taoudenni
# Processing Record 18 of Set 5 | karukh
# Processing Record 19 of Set 5 | kasongo
# Processing Record 20 of Set 5 | kambove
# Processing Record 21 of Set 5 | borkum
# Processing Record 22 of Set 5 | urumqi
# Processing Record 23 of Set 5 | tucupita
# Processing Record 24 of Set 5 | tangalle
# Processing Record 25 of Set 5 | mitu
# Processing Record 26 of Set 5 | chipata
# Processing Record 27 of Set 5 | piacabucu
# Processing Record 28 of Set 5 | lompoc
# Processing Record 29 of Set 5 | nguigmi
# Processing Record 30 of Set 5 | lebu
# Processing Record 31 of Set 5 | saudarkrokur
# Processing Record 32 of Set 5 | tenno
# Processing Record 33 of Set 5 | inirida
# Processing Record 34 of Set 5 | winkler
# Processing Record 35 of Set 5 | georgetown
# Processing Record 36 of Set 5 | itoman
# Processing Record 37 of Set 5 | svetlyy
# Processing Record 38 of Set 5 | tanki leendert
# City not found. Skipping...
# Processing Record 39 of Set 5 | malanje
# Processing Record 40 of Set 5 | turpan
# Processing Record 41 of Set 5 | kasempa
# Processing Record 42 of Set 5 | cabo san lucas
# Processing Record 43 of Set 5 | mount isa
# Processing Record 44 of Set 5 | crane
# Processing Record 45 of Set 5 | kyabe
# Processing Record 46 of Set 5 | mount pearl
# Processing Record 47 of Set 5 | ust-nera
# Processing Record 48 of Set 5 | fort st. john
# Processing Record 49 of Set 5 | panjab
# Processing Record 0 of Set 6 | merrill
# Processing Record 1 of Set 6 | ghanzi
# Processing Record 2 of Set 6 | wanning
# Processing Record 3 of Set 6 | saipan
# Processing Record 4 of Set 6 | hakui
# Processing Record 5 of Set 6 | port saint john's
# Processing Record 6 of Set 6 | la ronge
# Processing Record 7 of Set 6 | vernon
# Processing Record 8 of Set 6 | ialibu
# Processing Record 9 of Set 6 | vila franca do campo
# Processing Record 10 of Set 6 | port lincoln
# Processing Record 11 of Set 6 | touros
# Processing Record 12 of Set 6 | chernomorskoye
# Processing Record 13 of Set 6 | selfoss
# Processing Record 14 of Set 6 | petawawa
# Processing Record 15 of Set 6 | puerto carreno
# Processing Record 16 of Set 6 | nuriootpa
# Processing Record 17 of Set 6 | bodo
# Processing Record 18 of Set 6 | levelland
# Processing Record 19 of Set 6 | porto novo
# Processing Record 20 of Set 6 | popondetta
# Processing Record 21 of Set 6 | kapuskasing
# Processing Record 22 of Set 6 | guider
# Processing Record 23 of Set 6 | utrik
# Processing Record 24 of Set 6 | morococha
# Processing Record 25 of Set 6 | slavyanka
# Processing Record 26 of Set 6 | nema
# Processing Record 27 of Set 6 | indramayu
# Processing Record 28 of Set 6 | lorengau
# Processing Record 29 of Set 6 | fort bragg
# Processing Record 30 of Set 6 | rosetta
# Processing Record 31 of Set 6 | isangel
# Processing Record 32 of Set 6 | fukuecho
# Processing Record 33 of Set 6 | enewetak
# Processing Record 34 of Set 6 | uliastay
# Processing Record 35 of Set 6 | mount pleasant
# Processing Record 36 of Set 6 | mount gambier
# Processing Record 37 of Set 6 | aykhal
# Processing Record 38 of Set 6 | baise city
# Processing Record 39 of Set 6 | lubang
# Processing Record 40 of Set 6 | puerto penasco
# Processing Record 41 of Set 6 | sandnessjoen
# Processing Record 42 of Set 6 | margate
# Processing Record 43 of Set 6 | lincheng
# Processing Record 44 of Set 6 | alto araguaia
# Processing Record 45 of Set 6 | shingu
# Processing Record 46 of Set 6 | nikolayevsk-on-amure
# Processing Record 47 of Set 6 | puerto deseado
# Processing Record 48 of Set 6 | ketchikan
# Processing Record 49 of Set 6 | maslyanino
# Processing Record 0 of Set 7 | matthew town
# Processing Record 1 of Set 7 | tezu
# Processing Record 2 of Set 7 | omaruru
# Processing Record 3 of Set 7 | mejit
# Processing Record 4 of Set 7 | saint-philippe
# Processing Record 5 of Set 7 | augusto correa
# Processing Record 6 of Set 7 | nenjiang
# Processing Record 7 of Set 7 | northam
# Processing Record 8 of Set 7 | salinopolis
# Processing Record 9 of Set 7 | forfar
# Processing Record 10 of Set 7 | tolanaro
# Processing Record 11 of Set 7 | biltine
# Processing Record 12 of Set 7 | nasiriyah
# Processing Record 13 of Set 7 | edirne
# Processing Record 14 of Set 7 | zaragoza
# Processing Record 15 of Set 7 | misratah
# Processing Record 16 of Set 7 | tambacounda
# Processing Record 17 of Set 7 | udgir
# Processing Record 18 of Set 7 | nar'yan-mar
# Processing Record 19 of Set 7 | afaahiti
# Processing Record 20 of Set 7 | namibe
# Processing Record 21 of Set 7 | altai
# Processing Record 22 of Set 7 | praia da vitoria
# Processing Record 23 of Set 7 | mahina
# Processing Record 24 of Set 7 | trairi
# Processing Record 25 of Set 7 | cockburn town
# Processing Record 26 of Set 7 | harstad
# Processing Record 27 of Set 7 | pidhorodne
# Processing Record 28 of Set 7 | la sarre
# Processing Record 29 of Set 7 | tralee
# Processing Record 30 of Set 7 | kataragama
# City not found. Skipping...
# Processing Record 31 of Set 7 | obock
# Processing Record 32 of Set 7 | lethbridge
# Processing Record 33 of Set 7 | bryne
# Processing Record 34 of Set 7 | faya-largeau
# Processing Record 35 of Set 7 | constitucion
# Processing Record 36 of Set 7 | anderson
# Processing Record 37 of Set 7 | al ghayzah
# Processing Record 38 of Set 7 | christchurch
# Processing Record 39 of Set 7 | hammerfest
# Processing Record 40 of Set 7 | gummi
# Processing Record 41 of Set 7 | kill devil hills
# Processing Record 42 of Set 7 | egersund
# Processing Record 43 of Set 7 | val-d'or
# Processing Record 44 of Set 7 | naracoorte
# Processing Record 45 of Set 7 | neka
# Processing Record 46 of Set 7 | cradock
# Processing Record 47 of Set 7 | mata-utu
# Processing Record 48 of Set 7 | leh
# Processing Record 49 of Set 7 | sanga-sanga
# Processing Record 0 of Set 8 | jiayuguan
# Processing Record 1 of Set 8 | haiku-pauwela
# Processing Record 2 of Set 8 | santa terezinha
# Processing Record 3 of Set 8 | tieli
# Processing Record 4 of Set 8 | ta`u
# Processing Record 5 of Set 8 | ad dabbah
# Processing Record 6 of Set 8 | alotau
# City not found. Skipping...
# Processing Record 7 of Set 8 | betio village
# Processing Record 8 of Set 8 | mancio lima
# Processing Record 9 of Set 8 | heihe
# Processing Record 10 of Set 8 | muzayri'
# City not found. Skipping...
# Processing Record 11 of Set 8 | zabol
# Processing Record 12 of Set 8 | ahau
# City not found. Skipping...
# Processing Record 13 of Set 8 | lluta
# Processing Record 14 of Set 8 | lospalos
# Processing Record 15 of Set 8 | arraial do cabo
# Processing Record 16 of Set 8 | djibo
# Processing Record 17 of Set 8 | nogliki
# Processing Record 18 of Set 8 | puerto quijarro
# Processing Record 19 of Set 8 | port douglas
# Processing Record 20 of Set 8 | uray
# Processing Record 21 of Set 8 | rio negrinho
# Processing Record 22 of Set 8 | san patricio
# Processing Record 23 of Set 8 | vila velha
# Processing Record 24 of Set 8 | saint-pierre
# Processing Record 25 of Set 8 | dassa-zoume
# Processing Record 26 of Set 8 | vicam
# Processing Record 27 of Set 8 | havre
# Processing Record 28 of Set 8 | port mathurin
# Processing Record 29 of Set 8 | robore
# Processing Record 30 of Set 8 | luanda
# Processing Record 31 of Set 8 | ancud
# Processing Record 32 of Set 8 | bakchar
# Processing Record 33 of Set 8 | chiplun
# Processing Record 34 of Set 8 | protaras
# Processing Record 35 of Set 8 | palikir - national government center
# Processing Record 36 of Set 8 | priargunsk
# Processing Record 37 of Set 8 | zwedru
# Processing Record 38 of Set 8 | aripuana
# Processing Record 39 of Set 8 | fisterra
# Processing Record 40 of Set 8 | mandalgovi
# Processing Record 41 of Set 8 | zhangye
# Processing Record 42 of Set 8 | guerrero negro
# Processing Record 43 of Set 8 | antsiranana
# Processing Record 44 of Set 8 | duyun
# Processing Record 45 of Set 8 | rusape
# Processing Record 46 of Set 8 | laguna
# Processing Record 47 of Set 8 | ilhabela
# Processing Record 48 of Set 8 | tabou
# Processing Record 49 of Set 8 | sinop
# Processing Record 0 of Set 9 | illizi
# Processing Record 1 of Set 9 | saratamata
# City not found. Skipping...
# Processing Record 2 of Set 9 | mili
# Processing Record 3 of Set 9 | damongo
# City not found. Skipping...
# Processing Record 4 of Set 9 | sarina
# Processing Record 5 of Set 9 | ulladulla
# Processing Record 6 of Set 9 | kokopo
# Processing Record 7 of Set 9 | jeju city
# Processing Record 8 of Set 9 | santa ana de yacuma
# Processing Record 9 of Set 9 | castillos
# Processing Record 10 of Set 9 | 'ohonua
# City not found. Skipping...
# Processing Record 11 of Set 9 | nantucket
# Processing Record 12 of Set 9 | vodice
# Processing Record 13 of Set 9 | glace bay
# Processing Record 14 of Set 9 | mapastepec
# Processing Record 15 of Set 9 | uturoa
# Processing Record 16 of Set 9 | keflavik
# Processing Record 17 of Set 9 | ebon
# Processing Record 18 of Set 9 | paita
# Processing Record 19 of Set 9 | karratha
# Processing Record 20 of Set 9 | artigas
# Processing Record 21 of Set 9 | opuwo
# Processing Record 22 of Set 9 | bikenibeu village
# Processing Record 23 of Set 9 | road town
# Processing Record 24 of Set 9 | igarka
# Processing Record 25 of Set 9 | cambridge
# Processing Record 26 of Set 9 | filadelfia
# Processing Record 27 of Set 9 | sanawad
# Processing Record 28 of Set 9 | canutama
# Processing Record 29 of Set 9 | greenville
# Processing Record 30 of Set 9 | nuuk
# Processing Record 31 of Set 9 | muynoq
# Processing Record 32 of Set 9 | ikalamavony
# Processing Record 33 of Set 9 | talavera
# Processing Record 34 of Set 9 | concepcion
# Processing Record 35 of Set 9 | severo-yeniseyskiy
# Processing Record 36 of Set 9 | horta
# Processing Record 37 of Set 9 | kinablangan
# Processing Record 38 of Set 9 | kiama
# Processing Record 39 of Set 9 | baiti
# Processing Record 40 of Set 9 | bokani
# Processing Record 41 of Set 9 | lieksa
# Processing Record 42 of Set 9 | menongue
# Processing Record 43 of Set 9 | lhasa
# Processing Record 44 of Set 9 | nukunonu
# City not found. Skipping...
# Processing Record 45 of Set 9 | saldanha
# Processing Record 46 of Set 9 | mersa matruh
# Processing Record 47 of Set 9 | kawthoung
# City not found. Skipping...
# Processing Record 48 of Set 9 | namtsy
# Processing Record 49 of Set 9 | lyantor
# Processing Record 0 of Set 10 | estevan
# Processing Record 1 of Set 10 | al bardiyah
# Processing Record 2 of Set 10 | san julian
# Processing Record 3 of Set 10 | anna regina
# Processing Record 4 of Set 10 | harbin
# Processing Record 5 of Set 10 | micheweni
# Processing Record 6 of Set 10 | joshimath
# Processing Record 7 of Set 10 | weno
# Processing Record 8 of Set 10 | al hufuf
# Processing Record 9 of Set 10 | vadso
# Processing Record 10 of Set 10 | kangding
# Processing Record 11 of Set 10 | kabo
# Processing Record 12 of Set 10 | maues
# Processing Record 13 of Set 10 | kingston
# Processing Record 14 of Set 10 | vail
# Processing Record 15 of Set 10 | santo antonio
# Processing Record 16 of Set 10 | tosontsengel
# Processing Record 17 of Set 10 | acarau
# Processing Record 18 of Set 10 | santiago de cao
# Processing Record 19 of Set 10 | vingt cinq
# City not found. Skipping...
# Processing Record 20 of Set 10 | al burayqah
# Processing Record 21 of Set 10 | new norfolk
# Processing Record 22 of Set 10 | kuta
# Processing Record 23 of Set 10 | santo antonio do ica
# Processing Record 24 of Set 10 | bhabhua
# Processing Record 25 of Set 10 | taulaga
# Processing Record 26 of Set 10 | ust'-uda
# Processing Record 27 of Set 10 | sao felix do xingu
# Processing Record 28 of Set 10 | zeya
# Processing Record 29 of Set 10 | datu piang
# Processing Record 30 of Set 10 | liuli
# Processing Record 31 of Set 10 | san luis de la loma
# Processing Record 32 of Set 10 | kemijarvi
# Processing Record 33 of Set 10 | neiafu
# Processing Record 34 of Set 10 | maceio
# Processing Record 35 of Set 10 | mandan
# Processing Record 36 of Set 10 | repatriacion
# Processing Record 37 of Set 10 | yangor
# City not found. Skipping...
# Processing Record 38 of Set 10 | dalandzadgad
# Processing Record 39 of Set 10 | lembar
# City not found. Skipping...
# Processing Record 40 of Set 10 | fort mcmurray
# Processing Record 41 of Set 10 | salah bey
# Processing Record 42 of Set 10 | sagalo
# City not found. Skipping...
# Processing Record 43 of Set 10 | peniche
# Processing Record 44 of Set 10 | novi pazar
# Processing Record 45 of Set 10 | winnemucca
# Processing Record 46 of Set 10 | i-n-salah
# Processing Record 47 of Set 10 | bamboo flat
# Processing Record 48 of Set 10 | vredendal
# Processing Record 49 of Set 10 | el-tor
# Processing Record 0 of Set 11 | tadine
# Processing Record 1 of Set 11 | mugia
# Processing Record 2 of Set 11 | sansanne-mango
# Processing Record 3 of Set 11 | lakatoro
# Processing Record 4 of Set 11 | andkhoy
# Processing Record 5 of Set 11 | yigo village
# Processing Record 6 of Set 11 | rawlins
# Processing Record 7 of Set 11 | fortuna
# Processing Record 8 of Set 11 | urangan
# Processing Record 9 of Set 11 | hami
# Processing Record 10 of Set 11 | moyynkum
# Processing Record 11 of Set 11 | aleg
# Processing Record 12 of Set 11 | mossel bay
# Processing Record 13 of Set 11 | east london
# Processing Record 14 of Set 11 | atherton
# Processing Record 15 of Set 11 | ciudad lazaro cardenas
# Processing Record 16 of Set 11 | sanctuary point
# Processing Record 17 of Set 11 | upata
# Processing Record 18 of Set 11 | fremont
# Processing Record 19 of Set 11 | tofol
# Processing Record 20 of Set 11 | maragogi
# Processing Record 21 of Set 11 | amos
# Processing Record 22 of Set 11 | prokop'yevsk
# Processing Record 23 of Set 11 | tomohon
# Processing Record 24 of Set 11 | callao
# Processing Record 25 of Set 11 | cargados carajos
# City not found. Skipping...
# Processing Record 26 of Set 11 | parauna
# Processing Record 27 of Set 11 | sao joao da barra
# Processing Record 28 of Set 11 | jinchang
# Processing Record 29 of Set 11 | west fargo
# Processing Record 30 of Set 11 | pingdu
# Processing Record 31 of Set 11 | nizhnedevitsk
# Processing Record 32 of Set 11 | port sudan
# Processing Record 33 of Set 11 | beau vallon
# Processing Record 34 of Set 11 | spas-demensk
# Processing Record 35 of Set 11 | iquitos
# Processing Record 36 of Set 11 | barcelos
# Processing Record 37 of Set 11 | alpena
# Processing Record 38 of Set 11 | arno
# Processing Record 39 of Set 11 | tual
# Processing Record 40 of Set 11 | colonia
# Processing Record 41 of Set 11 | fort morgan
# Processing Record 42 of Set 11 | byron bay
# Processing Record 43 of Set 11 | bouarfa
# Processing Record 44 of Set 11 | wajir
# Processing Record 45 of Set 11 | kohat
# Processing Record 46 of Set 11 | ingeniero jacobacci
# Processing Record 47 of Set 11 | bonny
# Processing Record 48 of Set 11 | oakland
# Processing Record 49 of Set 11 | arteche
# Processing Record 0 of Set 12 | shache
# Processing Record 1 of Set 12 | las heras
# Processing Record 2 of Set 12 | terekeka
# City not found. Skipping...
# Processing Record 3 of Set 12 | chela
# Processing Record 4 of Set 12 | homer
# Processing Record 5 of Set 12 | giado
# Processing Record 6 of Set 12 | bokakhat
# Processing Record 7 of Set 12 | aswan
# Processing Record 8 of Set 12 | westport
# Processing Record 9 of Set 12 | kingscliff
# Processing Record 10 of Set 12 | dryden
# Processing Record 11 of Set 12 | ekibastuz
# Processing Record 12 of Set 12 | yei
# Processing Record 13 of Set 12 | baie-comeau
# Processing Record 14 of Set 12 | cooma
# Processing Record 15 of Set 12 | tokar
# Processing Record 16 of Set 12 | keelung
# Processing Record 17 of Set 12 | lubao
# Processing Record 18 of Set 12 | west bay
# Processing Record 19 of Set 12 | rabo de peixe
# Processing Record 20 of Set 12 | panino
# Processing Record 21 of Set 12 | neutraubling
# Processing Record 22 of Set 12 | balykshi
# Processing Record 23 of Set 12 | yelizovo
# Processing Record 24 of Set 12 | isla mujeres
# Processing Record 25 of Set 12 | maintirano
# Processing Record 26 of Set 12 | bonawon
# Processing Record 27 of Set 12 | sungai penuh
# Processing Record 28 of Set 12 | lazaro cardenas
# Processing Record 29 of Set 12 | ribeira brava
# Processing Record 30 of Set 12 | jinja
# Processing Record 31 of Set 12 | shuangyang
# Processing Record 32 of Set 12 | gunjur
# Processing Record 33 of Set 12 | medina de rioseco
# Processing Record 34 of Set 12 | olyokminsk
# Processing Record 35 of Set 12 | amol
# Processing Record 36 of Set 12 | kruisfontein
# Processing Record 37 of Set 12 | farafangana
# Processing Record 38 of Set 12 | kuala terengganu
# Processing Record 39 of Set 12 | cestos city
# Processing Record 40 of Set 12 | larache
# Processing Record 41 of Set 12 | nazyvayevsk
# Processing Record 42 of Set 12 | ulaangom
# Processing Record 43 of Set 12 | turka
# Processing Record 44 of Set 12 | gwanda
# Processing Record 45 of Set 12 | cadale
# Processing Record 46 of Set 12 | kalkaman
# Processing Record 47 of Set 12 | rikaze
# Processing Record 48 of Set 12 | kasongo-lunda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Set the API base URL
url = # YOUR CODE HERE

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = # YOUR CODE HERE
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = # YOUR CODE HERE

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = # YOUR CODE HERE
        city_lng = # YOUR CODE HERE
        city_max_temp = # YOUR CODE HERE
        city_humidity = # YOUR CODE HERE
        city_clouds = # YOUR CODE HERE
        city_wind = # YOUR CODE HERE
        city_country = # YOUR CODE HERE
        city_date = # YOUR CODE HERE

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | faya
# Processing Record 2 of Set 1 | farsund
# Processing Record 3 of Set 1 | new norfolk
# Processing Record 4 of Set 1 | jamestown
# Processing Record 5 of Set 1 | lanzhou
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | carnarvon
# Processing Record 9 of Set 1 | sisimiut
# Processing Record 10 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 1 | saint-pierre
# Processing Record 12 of Set 1 | colorado
# Processing Record 13 of Set 1 | nikolskoye
# Processing Record 14 of Set 1 | trairi
# Processing Record 15 of Set 1 | dobryanka
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | khatanga
# Processing Record 19 of Set 1 | tasiilaq
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | nuevo laredo
# Processing Record 24 of Set 1 | guiratinga
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | dukat
# Processing Record 29 of Set 1 | constitucion
# Processing Record 30 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 1 | senneterre
# Processing Record 32 of Set 1 | bambous virieux
# Processing Record 33 of Set 1 | zangakatun
# Processing Record 34 of Set 1 | saint-louis
# Processing Record 35 of Set 1 | midwest city
# Processing Record 36 of Set 1 | grimmen
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | stornoway
# Processing Record 39 of Set 1 | naberera
# Processing Record 40 of Set 1 | chokurdakh
# Processing Record 41 of Set 1 | drochia
# Processing Record 42 of Set 1 | klaksvik
# Processing Record 43 of Set 1 | labuhan
# Processing Record 44 of Set 1 | tomatlan
# Processing Record 45 of Set 1 | clyde river
# Processing Record 46 of Set 1 | sao joao da barra
# Processing Record 47 of Set 1 | margate
# Processing Record 48 of Set 1 | ancud
# Processing Record 49 of Set 1 | collierville
# Processing Record 50 of Set 1 | kapaa
# Processing Record 0 of Set 2 | mogadishu
# Processing Record 1 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 2 | tsalka
# Processing Record 3 of Set 2 | dalby
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | hilo
# Processing Record 7 of Set 2 | businga
# Processing Record 8 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 9 of Set 2 | lasa
# Processing Record 10 of Set 2 | vaini
# Processing Record 11 of Set 2 | cayenne
# Processing Record 12 of Set 2 | ust-kulom
# Processing Record 13 of Set 2 | udachnyy
# Processing Record 14 of Set 2 | east london
# Processing Record 15 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 2 | busselton
# Processing Record 17 of Set 2 | airai
# Processing Record 18 of Set 2 | grindavik
# Processing Record 19 of Set 2 | barrow
# Processing Record 20 of Set 2 | banda
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | hermanus
# Processing Record 23 of Set 2 | mar del plata
# Processing Record 24 of Set 2 | caravelas
# Processing Record 25 of Set 2 | port lincoln
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 | mendi
# Processing Record 28 of Set 2 | cobija
# Processing Record 29 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 2 | deer lake
# Processing Record 31 of Set 2 | nalut
# Processing Record 32 of Set 2 | saskylakh
# Processing Record 33 of Set 2 | dudinka
# Processing Record 34 of Set 2 | zamberk
# Processing Record 35 of Set 2 | jaguariaiva
# Processing Record 36 of Set 2 | aberdeen
# Processing Record 37 of Set 2 | mahebourg
# Processing Record 38 of Set 2 | kedrovyy
# Processing Record 39 of Set 2 | makakilo city
# Processing Record 40 of Set 2 | qostanay
# Processing Record 41 of Set 2 | esperance
# Processing Record 42 of Set 2 | darnah
# Processing Record 43 of Set 2 | provideniya
# Processing Record 44 of Set 2 | rafaela
# Processing Record 45 of Set 2 | saint-philippe
# Processing Record 46 of Set 2 | ponta do sol
# Processing Record 47 of Set 2 | solnechnyy
# Processing Record 48 of Set 2 | saint george
# Processing Record 49 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 0 of Set 3 | alba
# Processing Record 1 of Set 3 | kobojango
# City not found. Skipping...
# Processing Record 2 of Set 3 | arman
# Processing Record 3 of Set 3 | ugoofaaru
# Processing Record 4 of Set 3 | butaritari
# Processing Record 5 of Set 3 | kavaratti
# Processing Record 6 of Set 3 | zhangye
# Processing Record 7 of Set 3 | shenjiamen
# Processing Record 8 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 3 | itarema
# Processing Record 10 of Set 3 | trincomalee
# Processing Record 11 of Set 3 | castro
# Processing Record 12 of Set 3 | heihe
# Processing Record 13 of Set 3 | rio gallegos
# Processing Record 14 of Set 3 | siavonga
# Processing Record 15 of Set 3 | bluff
# Processing Record 16 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 3 | nova olimpia
# Processing Record 18 of Set 3 | palencia
# Processing Record 19 of Set 3 | inhambane
# Processing Record 20 of Set 3 | iqaluit
# Processing Record 21 of Set 3 | lebu
# Processing Record 22 of Set 3 | calabozo
# Processing Record 23 of Set 3 | sao filipe
# Processing Record 24 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 25 of Set 3 | torbay
# Processing Record 26 of Set 3 | kavieng
# Processing Record 27 of Set 3 | yidu
# Processing Record 28 of Set 3 | kawana waters
# City not found. Skipping...
# Processing Record 29 of Set 3 | cedar city
# Processing Record 30 of Set 3 | victoria
# Processing Record 31 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 3 | faanui
# Processing Record 33 of Set 3 | arraial do cabo
# Processing Record 34 of Set 3 | hithadhoo
# Processing Record 35 of Set 3 | port alfred
# Processing Record 36 of Set 3 | lichuan
# Processing Record 37 of Set 3 | talnakh
# Processing Record 38 of Set 3 | novorzhev
# Processing Record 39 of Set 3 | muncar
# Processing Record 40 of Set 3 | jashpurnagar
# Processing Record 41 of Set 3 | chuy
# Processing Record 42 of Set 3 | kulykivka
# Processing Record 43 of Set 3 | half moon bay
# Processing Record 44 of Set 3 | bocana de paiwas
# Processing Record 45 of Set 3 | el alto
# Processing Record 46 of Set 3 | sitka
# Processing Record 47 of Set 3 | punta arenas
# Processing Record 48 of Set 3 | bay city
# Processing Record 49 of Set 3 | baruun-urt
# Processing Record 0 of Set 4 | alotau
# City not found. Skipping...
# Processing Record 1 of Set 4 | ambon
# Processing Record 2 of Set 4 | corowa
# Processing Record 3 of Set 4 | port elizabeth
# Processing Record 4 of Set 4 | ocos
# Processing Record 5 of Set 4 | georgetown
# Processing Record 6 of Set 4 | tuktoyaktuk
# Processing Record 7 of Set 4 | brenham
# Processing Record 8 of Set 4 | peniche
# Processing Record 9 of Set 4 | tawang
# Processing Record 10 of Set 4 | havelock
# Processing Record 11 of Set 4 | novobelokatay
# Processing Record 12 of Set 4 | puerto del rosario
# Processing Record 13 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 4 | mount gambier
# Processing Record 15 of Set 4 | rindal
# Processing Record 16 of Set 4 | roseburg
# Processing Record 17 of Set 4 | kaeo
# Processing Record 18 of Set 4 | biak
# Processing Record 19 of Set 4 | kahului
# Processing Record 20 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 4 | lavrentiya
# Processing Record 22 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 4 | sabang
# Processing Record 24 of Set 4 | pangnirtung
# Processing Record 25 of Set 4 | corn island
# Processing Record 26 of Set 4 | innisfail
# Processing Record 27 of Set 4 | almaznyy
# Processing Record 28 of Set 4 | geraldton
# Processing Record 29 of Set 4 | burica
# City not found. Skipping...
# Processing Record 30 of Set 4 | kokopo
# Processing Record 31 of Set 4 | yellowknife
# Processing Record 32 of Set 4 | sao miguel do araguaia
# Processing Record 33 of Set 4 | belmonte
# Processing Record 34 of Set 4 | pisco
# Processing Record 35 of Set 4 | ambilobe
# Processing Record 36 of Set 4 | aripuana
# Processing Record 37 of Set 4 | kaitangata
# Processing Record 38 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 4 | lesnoy
# Processing Record 40 of Set 4 | evensk
# Processing Record 41 of Set 4 | sur
# Processing Record 42 of Set 4 | la ronge
# Processing Record 43 of Set 4 | danielskuil
# Processing Record 44 of Set 4 | chunhuhub
# Processing Record 45 of Set 4 | avera
# Processing Record 46 of Set 4 | ouallam
# Processing Record 47 of Set 4 | challapata
# Processing Record 48 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 4 | olafsvik
# Processing Record 0 of Set 5 | neepawa
# Processing Record 1 of Set 5 | freetown
# Processing Record 2 of Set 5 | nome
# Processing Record 3 of Set 5 | hovd
# Processing Record 4 of Set 5 | ugra
# Processing Record 5 of Set 5 | upernavik
# Processing Record 6 of Set 5 | sembakung
# Processing Record 7 of Set 5 | shakawe
# Processing Record 8 of Set 5 | upington
# Processing Record 9 of Set 5 | gwanda
# Processing Record 10 of Set 5 | kruisfontein
# Processing Record 11 of Set 5 | grand gaube
# Processing Record 12 of Set 5 | cacahuatepec
# Processing Record 13 of Set 5 | paita
# Processing Record 14 of Set 5 | bumba
# Processing Record 15 of Set 5 | maragogi
# Processing Record 16 of Set 5 | kosa
# Processing Record 17 of Set 5 | lagoa
# Processing Record 18 of Set 5 | cabra
# Processing Record 19 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 20 of Set 5 | gat
# Processing Record 21 of Set 5 | buala
# Processing Record 22 of Set 5 | asau
# Processing Record 23 of Set 5 | isangel
# Processing Record 24 of Set 5 | pevek
# Processing Record 25 of Set 5 | husavik
# Processing Record 26 of Set 5 | kodiak
# Processing Record 27 of Set 5 | zyryanka
# Processing Record 28 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 5 | valparaiso
# Processing Record 30 of Set 5 | baykit
# Processing Record 31 of Set 5 | port moresby
# Processing Record 32 of Set 5 | meulaboh
# Processing Record 33 of Set 5 | nakamura
# Processing Record 34 of Set 5 | simao
# Processing Record 35 of Set 5 | laguna
# Processing Record 36 of Set 5 | bethel
# Processing Record 37 of Set 5 | kodinsk
# Processing Record 38 of Set 5 | luderitz
# Processing Record 39 of Set 5 | touros
# Processing Record 40 of Set 5 | glasgow
# Processing Record 41 of Set 5 | ladario
# Processing Record 42 of Set 5 | sao teotonio
# Processing Record 43 of Set 5 | puri
# Processing Record 44 of Set 5 | yumbe
# Processing Record 45 of Set 5 | pangkalanbuun
# Processing Record 46 of Set 5 | hay river
# Processing Record 47 of Set 5 | verkhniye achaluki
# Processing Record 48 of Set 5 | terrace bay
# Processing Record 49 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 0 of Set 6 | ust-koksa
# Processing Record 1 of Set 6 | sorong
# Processing Record 2 of Set 6 | longyearbyen
# Processing Record 3 of Set 6 | san patricio
# Processing Record 4 of Set 6 | san cristobal
# Processing Record 5 of Set 6 | lensk
# Processing Record 6 of Set 6 | carrollton
# Processing Record 7 of Set 6 | norman wells
# Processing Record 8 of Set 6 | makokou
# Processing Record 9 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 10 of Set 6 | llata
# Processing Record 11 of Set 6 | neiafu
# Processing Record 12 of Set 6 | moroni
# Processing Record 13 of Set 6 | cap malheureux
# Processing Record 14 of Set 6 | walvis bay
# Processing Record 15 of Set 6 | rawson
# Processing Record 16 of Set 6 | tikaitnagar
# Processing Record 17 of Set 6 | sembe
# Processing Record 18 of Set 6 | aksu
# Processing Record 19 of Set 6 | russkaya polyana
# Processing Record 20 of Set 6 | broken hill
# Processing Record 21 of Set 6 | cherskiy
# Processing Record 22 of Set 6 | beya
# Processing Record 23 of Set 6 | goba
# Processing Record 24 of Set 6 | ordzhonikidze
# Processing Record 25 of Set 6 | high rock
# Processing Record 26 of Set 6 | floro
# Processing Record 27 of Set 6 | balabac
# Processing Record 28 of Set 6 | bintulu
# Processing Record 29 of Set 6 | tchaourou
# Processing Record 30 of Set 6 | zhongshan
# Processing Record 31 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 6 | quatre cocos
# Processing Record 33 of Set 6 | prieska
# Processing Record 34 of Set 6 | pathanamthitta
# Processing Record 35 of Set 6 | comodoro rivadavia
# Processing Record 36 of Set 6 | sungaipenuh
# Processing Record 37 of Set 6 | aklavik
# Processing Record 38 of Set 6 | camacha
# Processing Record 39 of Set 6 | thompson
# Processing Record 40 of Set 6 | hambantota
# Processing Record 41 of Set 6 | swanton
# Processing Record 42 of Set 6 | san quintin
# Processing Record 43 of Set 6 | codrington
# Processing Record 44 of Set 6 | chapais
# Processing Record 45 of Set 6 | chengde
# Processing Record 46 of Set 6 | portland
# Processing Record 47 of Set 6 | berdigestyakh
# Processing Record 48 of Set 6 | coquimbo
# Processing Record 49 of Set 6 | samana
# Processing Record 0 of Set 7 | anchorage
# Processing Record 1 of Set 7 | fairbanks
# Processing Record 2 of Set 7 | cockburn town
# Processing Record 3 of Set 7 | tura
# Processing Record 4 of Set 7 | sakakah
# Processing Record 5 of Set 7 | ola
# Processing Record 6 of Set 7 | hasaki
# Processing Record 7 of Set 7 | jiuquan
# Processing Record 8 of Set 7 | tuatapere
# Processing Record 9 of Set 7 | kloulklubed
# Processing Record 10 of Set 7 | ust-maya
# Processing Record 11 of Set 7 | san juan
# Processing Record 12 of Set 7 | whitianga
# Processing Record 13 of Set 7 | praia
# Processing Record 14 of Set 7 | okitipupa
# Processing Record 15 of Set 7 | monmouth
# Processing Record 16 of Set 7 | san andres
# Processing Record 17 of Set 7 | lyngseidet
# Processing Record 18 of Set 7 | dunmore town
# Processing Record 19 of Set 7 | galegos
# Processing Record 20 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 21 of Set 7 | kamen-rybolov
# Processing Record 22 of Set 7 | dabat
# Processing Record 23 of Set 7 | camopi
# Processing Record 24 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 7 | jalu
# Processing Record 26 of Set 7 | eyl
# Processing Record 27 of Set 7 | valdivia
# Processing Record 28 of Set 7 | teguldet
# Processing Record 29 of Set 7 | aquiraz
# Processing Record 30 of Set 7 | ulaangom
# Processing Record 31 of Set 7 | souillac
# Processing Record 32 of Set 7 | vrakhnaiika
# City not found. Skipping...
# Processing Record 33 of Set 7 | alice springs
# Processing Record 34 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 7 | koriyama
# Processing Record 36 of Set 7 | kingman
# Processing Record 37 of Set 7 | college
# Processing Record 38 of Set 7 | la romana
# Processing Record 39 of Set 7 | daru
# Processing Record 40 of Set 7 | boden
# Processing Record 41 of Set 7 | carroll
# Processing Record 42 of Set 7 | ust-kuyga
# Processing Record 43 of Set 7 | bucerias
# Processing Record 44 of Set 7 | tandil
# Processing Record 45 of Set 7 | horsham
# Processing Record 46 of Set 7 | vao
# Processing Record 47 of Set 7 | bathsheba
# Processing Record 48 of Set 7 | salalah
# Processing Record 49 of Set 7 | harwich
# Processing Record 0 of Set 8 | sambava
# Processing Record 1 of Set 8 | yarada
# Processing Record 2 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 8 | namibe
# Processing Record 4 of Set 8 | kokkola
# Processing Record 5 of Set 8 | leningradskiy
# Processing Record 6 of Set 8 | vostok
# Processing Record 7 of Set 8 | rio grande
# Processing Record 8 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 9 of Set 8 | chegdomyn
# Processing Record 10 of Set 8 | ilulissat
# Processing Record 11 of Set 8 | viseu
# Processing Record 12 of Set 8 | cidreira
# Processing Record 13 of Set 8 | bafoulabe
# Processing Record 14 of Set 8 | swan river
# Processing Record 15 of Set 8 | rocha
# Processing Record 16 of Set 8 | juruti
# Processing Record 17 of Set 8 | kailua
# Processing Record 18 of Set 8 | verkh-suetka
# Processing Record 19 of Set 8 | dunedin
# Processing Record 20 of Set 8 | mount isa
# Processing Record 21 of Set 8 | mahina
# Processing Record 22 of Set 8 | kamloops
# Processing Record 23 of Set 8 | santa rosalia
# Processing Record 24 of Set 8 | nerchinskiy zavod
# Processing Record 25 of Set 8 | torrington
# Processing Record 26 of Set 8 | krutikha
# Processing Record 27 of Set 8 | bonavista
# Processing Record 28 of Set 8 | zaysan
# Processing Record 29 of Set 8 | mana
# Processing Record 30 of Set 8 | nemuro
# Processing Record 31 of Set 8 | mandera
# Processing Record 32 of Set 8 | numan
# Processing Record 33 of Set 8 | pingliang
# Processing Record 34 of Set 8 | saldanha
# Processing Record 35 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 8 | vila velha
# Processing Record 37 of Set 8 | bengkulu
# Processing Record 38 of Set 8 | honiara
# Processing Record 39 of Set 8 | pemba
# Processing Record 40 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 8 | ahipara
# Processing Record 42 of Set 8 | shingu
# Processing Record 43 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 8 | korla
# Processing Record 45 of Set 8 | lerik
# Processing Record 46 of Set 8 | quelimane
# Processing Record 47 of Set 8 | katyuzhanka
# Processing Record 48 of Set 8 | narwar
# Processing Record 49 of Set 8 | port hardy
# Processing Record 0 of Set 9 | sol-iletsk
# Processing Record 1 of Set 9 | tabou
# Processing Record 2 of Set 9 | saint anthony
# Processing Record 3 of Set 9 | srednekolymsk
# Processing Record 4 of Set 9 | homer
# Processing Record 5 of Set 9 | livingston
# Processing Record 6 of Set 9 | lima
# Processing Record 7 of Set 9 | christchurch
# Processing Record 8 of Set 9 | beitbridge
# Processing Record 9 of Set 9 | kortkeros
# Processing Record 10 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 11 of Set 9 | port hedland
# Processing Record 12 of Set 9 | fortuna
# Processing Record 13 of Set 9 | dicabisagan
# Processing Record 14 of Set 9 | smithers
# Processing Record 15 of Set 9 | peleduy
# Processing Record 16 of Set 9 | yulara
# Processing Record 17 of Set 9 | roebourne
# Processing Record 18 of Set 9 | mariinskiy posad
# Processing Record 19 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 20 of Set 9 | mayumba
# Processing Record 21 of Set 9 | adrar
# Processing Record 22 of Set 9 | port blair
# Processing Record 23 of Set 9 | komsomolskiy
# Processing Record 24 of Set 9 | ribeira grande
# Processing Record 25 of Set 9 | qasigiannguit
# Processing Record 26 of Set 9 | buraydah
# Processing Record 27 of Set 9 | port-gentil
# Processing Record 28 of Set 9 | saint-francois
# Processing Record 29 of Set 9 | vestmannaeyjar
# Processing Record 30 of Set 9 | bogande
# Processing Record 31 of Set 9 | quesnel
# Processing Record 32 of Set 9 | usman
# Processing Record 33 of Set 9 | aykhal
# Processing Record 34 of Set 9 | carlyle
# Processing Record 35 of Set 9 | kayerkan
# Processing Record 36 of Set 9 | moron
# Processing Record 37 of Set 9 | paamiut
# Processing Record 38 of Set 9 | hamilton
# Processing Record 39 of Set 9 | seoul
# Processing Record 40 of Set 9 | woodward
# Processing Record 41 of Set 9 | georgiyevskoye
# Processing Record 42 of Set 9 | mayo
# Processing Record 43 of Set 9 | kysyl-syr
# Processing Record 44 of Set 9 | tashara
# Processing Record 45 of Set 9 | acajutla
# Processing Record 46 of Set 9 | capoterra
# Processing Record 47 of Set 9 | muisne
# Processing Record 48 of Set 9 | praia da vitoria
# Processing Record 49 of Set 9 | maniitsoq
# Processing Record 0 of Set 10 | kalemie
# Processing Record 1 of Set 10 | tagusao
# Processing Record 2 of Set 10 | mao
# Processing Record 3 of Set 10 | mahibadhoo
# Processing Record 4 of Set 10 | cabo san lucas
# Processing Record 5 of Set 10 | panuco
# Processing Record 6 of Set 10 | hervey bay
# Processing Record 7 of Set 10 | fayaoue
# Processing Record 8 of Set 10 | stolac
# Processing Record 9 of Set 10 | gamboma
# Processing Record 10 of Set 10 | rundu
# Processing Record 11 of Set 10 | carutapera
# Processing Record 12 of Set 10 | port-de-bouc
# Processing Record 13 of Set 10 | nanortalik
# Processing Record 14 of Set 10 | dzaoudzi
# Processing Record 15 of Set 10 | aktau
# Processing Record 16 of Set 10 | lorengau
# Processing Record 17 of Set 10 | pachino
# Processing Record 18 of Set 10 | cabedelo
# Processing Record 19 of Set 10 | denpasar
# Processing Record 20 of Set 10 | ipixuna
# Processing Record 21 of Set 10 | broome
# Processing Record 22 of Set 10 | tilichiki
# Processing Record 23 of Set 10 | lakki marwat
# Processing Record 24 of Set 10 | veinticinco de mayo
# Processing Record 25 of Set 10 | avdon
# Processing Record 26 of Set 10 | katobu
# Processing Record 27 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 10 | merauke
# Processing Record 29 of Set 10 | yangliuqing
# Processing Record 30 of Set 10 | tieling
# Processing Record 31 of Set 10 | togur
# Processing Record 32 of Set 10 | thinadhoo
# Processing Record 33 of Set 10 | whitchurch-stouffville
# City not found. Skipping...
# Processing Record 34 of Set 10 | terra santa
# Processing Record 35 of Set 10 | colares
# Processing Record 36 of Set 10 | havoysund
# Processing Record 37 of Set 10 | ostrovnoy
# Processing Record 38 of Set 10 | alofi
# Processing Record 39 of Set 10 | samandag
# Processing Record 40 of Set 10 | san joaquin
# Processing Record 41 of Set 10 | treinta y tres
# Processing Record 42 of Set 10 | nazareno
# Processing Record 43 of Set 10 | tessalit
# Processing Record 44 of Set 10 | yaan
# Processing Record 45 of Set 10 | ixtapa
# Processing Record 46 of Set 10 | dong hoi
# Processing Record 47 of Set 10 | harindanga
# Processing Record 48 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 49 of Set 10 | pontypool
# Processing Record 0 of Set 11 | ulladulla
# Processing Record 1 of Set 11 | la paz
# Processing Record 2 of Set 11 | hualmay
# Processing Record 3 of Set 11 | barroso
# Processing Record 4 of Set 11 | vryburg
# Processing Record 5 of Set 11 | beira
# Processing Record 6 of Set 11 | the valley
# Processing Record 7 of Set 11 | narsaq
# Processing Record 8 of Set 11 | juegang
# Processing Record 9 of Set 11 | verkhniy avzyan
# Processing Record 10 of Set 11 | berdyuzhye
# City not found. Skipping...
# Processing Record 11 of Set 11 | araouane
# Processing Record 12 of Set 11 | kirakira
# Processing Record 13 of Set 11 | tautira
# Processing Record 14 of Set 11 | singkang
# Processing Record 15 of Set 11 | taitung
# Processing Record 16 of Set 11 | nabire
# Processing Record 17 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 11 | chifeng
# Processing Record 19 of Set 11 | caiaponia
# Processing Record 20 of Set 11 | salto
# Processing Record 21 of Set 11 | praya
# Processing Record 22 of Set 11 | aksarka
# Processing Record 23 of Set 11 | abu zabad
# Processing Record 24 of Set 11 | kushima
# Processing Record 25 of Set 11 | beaune
# Processing Record 26 of Set 11 | egvekinot
# Processing Record 27 of Set 11 | greenville
# Processing Record 28 of Set 11 | ust-ordynskiy
# Processing Record 29 of Set 11 | tranas
# Processing Record 30 of Set 11 | pleasanton
# Processing Record 31 of Set 11 | beringovskiy
# Processing Record 32 of Set 11 | newcastleton
# Processing Record 33 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 34 of Set 11 | hirado
# Processing Record 35 of Set 11 | brokopondo
# Processing Record 36 of Set 11 | batagay
# Processing Record 37 of Set 11 | laurel
# Processing Record 38 of Set 11 | statesville
# Processing Record 39 of Set 11 | tikrit
# Processing Record 40 of Set 11 | iisalmi
# Processing Record 41 of Set 11 | lahij
# Processing Record 42 of Set 11 | derzhavinsk
# Processing Record 43 of Set 11 | kyren
# Processing Record 44 of Set 11 | kapit
# Processing Record 45 of Set 11 | altay
# Processing Record 46 of Set 11 | waseca
# Processing Record 47 of Set 11 | nantucket
# Processing Record 48 of Set 11 | cadillac
# Processing Record 49 of Set 11 | sfantu gheorghe
# Processing Record 0 of Set 12 | kundiawa
# Processing Record 1 of Set 12 | gornopravdinsk
# Processing Record 2 of Set 12 | bhandara
# Processing Record 3 of Set 12 | wadi musa
# Processing Record 4 of Set 12 | charters towers
# Processing Record 5 of Set 12 | ustka
# Processing Record 6 of Set 12 | sawakin
# Processing Record 7 of Set 12 | severo-kurilsk
# Processing Record 8 of Set 12 | rameswaram
# Processing Record 9 of Set 12 | guerrero negro
# Processing Record 10 of Set 12 | bandarbeyla
# Processing Record 11 of Set 12 | antofagasta
# Processing Record 12 of Set 12 | vila franca do campo
# Processing Record 13 of Set 12 | bauta
# Processing Record 14 of Set 12 | nsanje
# Processing Record 15 of Set 12 | xuchang
# Processing Record 16 of Set 12 | todos santos
# Processing Record 17 of Set 12 | kuhestan
# City not found. Skipping...
# Processing Record 18 of Set 12 | bataipora
# Processing Record 19 of Set 12 | tateyama
# Processing Record 20 of Set 12 | wajima
# Processing Record 21 of Set 12 | pokosnoye
# Processing Record 22 of Set 12 | waipawa
# Processing Record 23 of Set 12 | yaring
# Processing Record 24 of Set 12 | isiro
# Processing Record 25 of Set 12 | chivilcoy
# Processing Record 26 of Set 12 | mandalgovi
# Processing Record 27 of Set 12 | nicoya
# Processing Record 28 of Set 12 | novocheremshansk
# Processing Record 29 of Set 12 | emirdag
# Processing Record 30 of Set 12 | nouadhibou
# Processing Record 31 of Set 12 | tongliao
# Processing Record 32 of Set 12 | ryomgard
# Processing Record 33 of Set 12 | khudumelapye
# Processing Record 34 of Set 12 | talcahuano
# Processing Record 35 of Set 12 | gifhorn
# Processing Record 36 of Set 12 | bilma
# Processing Record 37 of Set 12 | vung tau
# Processing Record 38 of Set 12 | byron bay
# Processing Record 39 of Set 12 | kalabo
# Processing Record 40 of Set 12 | arcata
# Processing Record 41 of Set 12 | lemoore
# Processing Record 42 of Set 12 | norfolk
# Processing Record 43 of Set 12 | juba
# Processing Record 44 of Set 12 | pali
# Processing Record 45 of Set 12 | katsuura
# Processing Record 46 of Set 12 | bambanglipuro
# Processing Record 47 of Set 12 | padang
# Processing Record 48 of Set 12 | freeport
# Processing Record 49 of Set 12 | bulgan
# Processing Record 0 of Set 13 | sorland
# Processing Record 1 of Set 13 | saryg-sep
# Processing Record 2 of Set 13 | batagay-alyta
# Processing Record 3 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 4 of Set 13 | lompoc
# Processing Record 5 of Set 13 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 6 of Set 13 | changli
# Processing Record 7 of Set 13 | choma
# Processing Record 8 of Set 13 | tena
# Processing Record 9 of Set 13 | ilhabela
# Processing Record 10 of Set 13 | redmond
# Processing Record 11 of Set 13 | wyndham
# Processing Record 12 of Set 13 | nhulunbuy
# Processing Record 13 of Set 13 | sangamner
# Processing Record 14 of Set 13 | road town
# Processing Record 15 of Set 13 | ranong
# Processing Record 16 of Set 13 | staryy nadym
# Processing Record 17 of Set 13 | dargaville
# Processing Record 18 of Set 13 | sovetskiy
# Processing Record 19 of Set 13 | tatarsk
# Processing Record 20 of Set 13 | canchungo
# Processing Record 21 of Set 13 | iquique
# Processing Record 22 of Set 13 | poum
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame.from_dict(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          575
# Lat           575
# Lng           575
# Max Temp      575
# Humidity      575
# Cloudiness    575
# Wind Speed    575
# Country       575
# Date          575
# dtype: int64

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = # YOUR CODE HERE

# Show Record Count
city_data_df.count()

# %%
# Display sample data
city_data_df.head()
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# 0                     sitka  57.0531 -135.3300     60.69        82
# 1  petropavlovsk-kamchatsky  53.0452  158.6483     55.99       100
# 2                 grytviken -54.2811  -36.5092     22.48        74
# 3                isafjordur  66.0755  -23.1240     60.84        72
# 4               san ignacio  17.1561  -89.0714     75.34       100
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        3.44      US  1693047018
# 1          75        2.24      RU  1693046721
# 2          72       22.37      GS  1693047019
# 3          75       17.27      IS  1693047020
# 4          75        4.61      BZ  1693047020

# %%
# Display sample data
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         faya  18.3851   42.4509     22.06        35          21        2.60
# 1      farsund  58.0948    6.8047     13.30       100           0        7.65
# 2  new norfolk -42.7826  147.0587     11.72        58          12        1.34
# 3    jamestown  42.0970  -79.2353      5.77        77         100        9.77
# 4      lanzhou  36.0564  103.7922     14.53        48          59        1.20
#
#   Country        Date
# 0      SA  1666108228
# 1      NO  1666108228
# 2      AU  1666108230
# 3      US  1666107934
# 4      CN  1666108230

# %%
# Export the City_Data into a csv
city_data_df.to_csv("C:/users/wambu/desktop/Python-api-challenge/WeatherPy/output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("C:/users/wambu/desktop/Python-api-challenge/WeatherPy/output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                              City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                           sitka  57.0531 -135.3300     60.69        82
# 1        petropavlovsk-kamchatsky  53.0452  158.6483     55.99       100
# 2                       grytviken -54.2811  -36.5092     22.48        74
# 3                      isafjordur  66.0755  -23.1240     60.84        72
# 4                     san ignacio  17.1561  -89.0714     75.34       100
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        3.44      US  1693047018
# 1                75        2.24      RU  1693046721
# 2                72       22.37      GS  1693047019
# 3                75       17.27      IS  1693047020
# 4                75        4.61      BZ  1693047020

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               faya  18.3851   42.4509     22.06        35          21
# 1            farsund  58.0948    6.8047     13.30       100           0
# 2        new norfolk -42.7826  147.0587     11.72        58          12
# 3          jamestown  42.0970  -79.2353      5.77        77         100
# 4            lanzhou  36.0564  103.7922     14.53        48          59
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 2              1.34      AU  1666108230
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], alpha=.8, edgecolors="k")

#Format date
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title(f"City Latitude vs. Temperature ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs. Humidity (%) ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title(f"City Latitude vs. Cloudiness ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], alpha=.8, edgecolors="k")

#Format date from UTC to m/d/y
date = datetime.now()
date = date.strftime("%m-%d-%Y")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.grid(True) 
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
#(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
#regress_values = x_values * slope + intercept
#line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) > 0, :]

# Display sample data
northern_hemi_df.head()
# Out:
#                              City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                           sitka  57.0531 -135.3300     60.69        82
# 1        petropavlovsk-kamchatsky  53.0452  158.6483     55.99       100
# 3                      isafjordur  66.0755  -23.1240     60.84        72
# 4                     san ignacio  17.1561  -89.0714     75.34       100
# 6                        la passe  45.5549   -0.8967     73.63        51
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        3.44      US  1693047018
# 1                75        2.24      RU  1693046721
# 3                75       17.27      IS  1693047020
# 4                75        4.61      BZ  1693047020
# 6                27       14.12      FR  1693047022

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[pd.to_numeric(city_data_df["Lat"]) < 0, :]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2             grytviken -54.2811  -36.5092     22.48        74          72
# 5                avarua -21.2078 -159.7750     77.05        88          40
# 10                 suva -18.1416  178.4415     67.48       100          75
# 11               olinda  -8.0089  -34.8553     73.13        94          20
# 12       port elizabeth -33.9180   25.5701     59.09        76          40
#
#          Wind Speed Country        Date
# City_ID
# 2             22.37      GS  1693047019
# 5             13.80      CK  1693046892
# 10             2.30      FJ  1693047024
# 11             4.61      BR  1693047009
# 12            31.07      ZA  1693047026

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(0,-20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The regression displays a negative relationship between temperature and latitude")
print("In the northern hemisphere, as the latitude increases the distance from the equator increases")
print("As you move away from the equator, the max temperature decreases.")
# Out:
# The r-value is -0.6743892574717477
# -----------------------------------
# Observations about linear relationship:
# The regression displays a negative relationship between temperature and latitude
# In the northern hemisphere, as the latitude increases the distance from the equator increases
# As you move away from the equator, the max temperature decreases.

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.7161472181434118

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The regression displays a sligtly positive relationship between temperature and latitude.")
print("In the southern hemisphere, as the latitude increases the distance from the equator decreases")
print("As you move closer to the equator, the max temperature generally increases.")
# Out:
# The r-value is 0.7778892950185647
# -----------------------------------
# Observations about linear relationship:
# The regression displays a sligtly positive relationship between temperature and latitude.
# In the southern hemisphere, as the latitude increases the distance from the equator decreases
# As you move closer to the equator, the max temperature generally increases.

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The relationship is slightly positive, though there doesn't appear to be a strong coorelation between humidity and latitude")
# Out:
# The r-value is 0.03926474608782493
# -----------------------------------
# Observations about linear relationship:
# The relationship is slightly positive, though there doesn't appear to be a strong coorelation between humidity and latitude

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,25),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("The relationship is slightly positive.")
print("Humidity increases as cities get closer to the equator.")
# Out:
# The r-value is -0.01077077477943906
# -----------------------------------
# Observations about linear relationship:
# The relationship is slightly positive.
# Humidity increases as cities get closer to the equator.

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(40,20),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and cloudiness.")
# Out:
# The r-value is 0.038928826559528326
# -----------------------------------
# Observations about linear relationship:
# There does not appear to be a coorelation between latitude and cloudiness.

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,15),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and cloudiness.")
# Out:
# The r-value is -0.08119443176029208
# -----------------------------------
# Observations about linear relationship:
# There does not appear to be a coorelation between latitude and cloudiness.

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(15,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and wind speed.")
# Out:
# The r-value is -0.05815479523108862
# -----------------------------------
# Observations about linear relationship:
# There does not appear to be a coorelation between latitude and wind speed.

# %%
# Northern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
slope = linregress(x_values, y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

#Plot values
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "-r")
plt.annotate(line_eq,(-25,10),fontsize=15,color="red")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
print(f'The r-value is {rvalue}')
print("-----------------------------------")
print("Observations about linear relationship:")
print("There does not appear to be a coorelation between latitude and wind speed.")
# Out:
# The r-value is -0.17283665097375725
# -----------------------------------
# Observations about linear relationship:
# There does not appear to be a coorelation between latitude and wind speed.

# %%
# Southern Hemisphere
# YOUR CODE HERE
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
